# %% [markdown]
# # Let's Strat

# %% [markdown]
# # Frist things first
#
# First of all import  opencv, numpy, and matplotlib.
#
# You may use command below for using matplotlib in jupyter notebook.
#
# ``%matplotlib inline  ``

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import cv2 as cv
import os
ROOT_DIR = os.path.dirname(os.path.abspath("."))
print(ROOT_DIR)
# Out:
# C:\Users\nimac\PycharmProjects\Python

# %% [markdown]
# # Read and Load images
#
# In this part we want to load an image. There are useful functions in cv2 for donig that. Use ``imread`` from cv2 to read ``lady-gaga.jpg``

# %%
lady = cv.imread("lady-gaga.jpg", cv.IMREAD_ANYCOLOR)
#cv.imshow("lady", lady)
plt.imshow(lady)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-afa498ee3885> in <module>()
#       1 lady = cv.imread(".\\vision3\\ap97\\hw1\\lady-gaga.jpg", cv.IMREAD_ANYCOLOR)
#       2 #cv.imshow("lady", lady)
# ----> 3 plt.imshow(lady)
#
# ~\PycharmProjects\Python\vision3\venvpy\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~\PycharmProjects\Python\vision3\venvpy\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %% [markdown]
# There are many options for reading an image too. You may use ``shift + tab``, when writing a function name in jupyter for further information.
#
# Use ``cv2.IMREAD_GRAYSCALE``, ``cv2.IMREAD_COLOR``, ``cv2.IMREAD_UNCHANGED`` options and create three new images ``image_1``, ``image_2``, ``image_3`` from ``lady-gaga.jpg`` with ``imread``
#
# Any guess about what they are ?

# %%
image_1 = cv.imread(IMG_DIR + "lady-gaga.jpg", cv.IMREAD_GRAYSCALE)
plt.imshow(image_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-33ba96d87d52> in <module>()
#       1 image_1 = cv.imread(IMG_DIR + "lady-gaga.jpg", cv.IMREAD_GRAYSCALE)
# ----> 2 plt.imshow(image_1)
#
# ~\PycharmProjects\Python\vision3\venvpy\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~\PycharmProjects\Python\vision3\venvpy\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
image_2 = cv.imread(IMG_DIR + "lady-gaga.jpg", cv.IMREAD_COLOR)
plt.imshow(image_2)

# %%
image_3 = cv.imread(IMG_DIR + "lady-gaga.jpg", cv.IMREAD_UNCHANGED)
cv.imshow("image3",image_3)

# %% [markdown]
# Guess: ?(:D) read images in grayScale color and unchanged

# %% [markdown]
# # Showing image
#
# In this section we want to show our image. There are many ways to do that.
#
# We will first use matplotlib, and then opencv for showing our images.

# %% [markdown]
# ## Show with matplotlib
#
# Use matplotlib built-in function ``imshow`` to show one of your images.

# %% [markdown]
# ## Show with opencv
#
# Use ``cv2.imshow`` to show one of your images. You may want to use ``cv2.waitKey``, and ``destroyAllWindows`` for terminating opencv workers.

# %% [markdown]
# # Write and save images
#
# Use ``imwrite`` to save one of your images in desired directory, you may want to name your saved image ``lagy-gaga2.jpg``

# %% [markdown]
# # Let's draw things on image

# %% [markdown]
# # Draw lines on the image
#
# Use ``line`` in opencv to draw line in one of your images.
#
# It should be like this form ``cv2.line(image, start_point, end_point, color, line_width)``. You may check whatever doc you want.
#
# color in opencv is in BGR format.
# <br>
# ``(255, 255, 255) -> white``
# <br>
# ``(0,0,0)         -> Black``
# <br>
# ``(255,0,0) -> Blue``
# <br>
# ``(0,255,0) -> Green``
# <br>
# ``(0,0,255) -> Red``

# %% [markdown]
# # Draw rectangle on the image
#
# Use ``rectangle`` in opencv to draw a rectangle in one of your images

# %% [markdown]
# # Draw circle on the image
# Use ``circle`` in opencv to draw a circle on your image.

# %% [markdown]
# # Connect points with lines
#
# Run cells below, and see what happens.

# %%
pts = np.array([[10, 5], [20, 30], [70, 40], [90, 120], [50, 5]], np.int32)

# %% [markdown]
# $True$ means you want the last point to be connected to the first point too.

# %%
cv2.polylines(img, [pts], True, (0, 255, 255), 5)

# %% [markdown]
# # Write text on the image

# %%
font = cv2.FONT_HERSHEY_COMPLEX
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d63217a45378> in <module>()
# ----> 1 font = cv2.FONT_HERSHEY_COMPLEX
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# Use ``font`` and write "__I Love Computer Vision__" on one of your images.
#
# You may use ``putText`` in opencv inorder to do it.

# %% [markdown]
# # Save
#
# Save all of your final works.

# %% [markdown]
# ### Don't ever forget about ``shift + tab`` in Jupyter Notebook.
#
# The End.
